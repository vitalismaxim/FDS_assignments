# %%
import pandas as pd
import config as cf
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
df_final = pd.read_pickle('./Data/Throughput/Speeches_processed_Happiness.pickle')

# %%
words_by_year = df_final.groupby('Year')['speech'].sum()

# %%
for year, text in words_by_year.items():
    print(year)
    wordcloud = WordCloud(width=600, height=400, max_font_size=90,
                                  max_words=50, stopwords=cf.sw,
                                  background_color="white").generate(text)

    # Display the generated image
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    wordcloud.to_file(f'./Data/Output/Wordclouds/wordcloud_{year}.png')
# Out:
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
